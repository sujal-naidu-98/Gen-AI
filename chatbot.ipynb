# %% [markdown]
# <a href="https://colab.research.google.com/github/sujal-naidu-98/Gen-AI/blob/main/chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U groq

from google.colab import userdata
from groq import Groq

api_key = userdata.get("GROQ_API_KEY")

if not api_key:
    print("❌ API key NOT found in Colab Secrets")
else:
    print("✅ API key found")

    client = Groq(api_key=api_key)

    try:
        models = client.models.list()

        print("\n✅ Groq API is working!")
        print("\nModels available to your API key:\n")

        for model in models.data:
            print(model.id)

    except Exception as e:
        print("\n❌ API ERROR:")
        print(e)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 7.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-groq 1.1.3 requires groq<1.0.0,>=0.30.0, but you have groq 1.7.0 which is incompatible.
# ✅ API key found
#
# ✅ Groq API is working!
#
# Models available to your API key:
#
# qwen/qwen3.8-27b
# qwen/qwen3.6-27b
# meta-llama/llama-prompt-guard-2-86m
# canopylabs/orpheus-arabic-saudi
# whisper-large-v3-turbo
# groq/compound-mini
# openai/gpt-oss-safeguard-20b
# canopylabs/orpheus-v1-english
# whisper-large-v3
# openai/gpt-oss-20b
# allam-2-7b
# meta-llama/llama-prompt-guard-2-22m
# groq/compound
# openai/gpt-oss-120b

# %%
# Install compatible versions
# !pip install -q -U "groq>=0.30.0,<1.0.0" "langchain-groq>=0.3.0"

# Imports
from google.colab import userdata
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage

# Get API key
groq_key = userdata.get("GROQ_API_KEY")

if not groq_key:
    raise ValueError("GROQ_API_KEY was not found in Colab Secrets.")

print("✅ API key found")

# Create chatbot
model = ChatGroq(
    model="openai/gpt-oss-20b",
    groq_api_key=groq_key,
    temperature=0.7
)

# Conversation history
messages = [
    SystemMessage(
        content="You are a helpful, friendly and simple AI assistant."
    )
]

print("\n================================")
print("        GROQ AI CHATBOT")
print("================================")
print("Type 'exit' or 'quit' to stop.\n")

# Chat loop
while True:

    user_msg = input("You: ").strip()

    # Exit
    if user_msg.lower() in ["exit", "quit"]:
        print("Bot: Bye! 👋")
        break

    # Ignore empty input
    if not user_msg:
        continue

    # Add user message
    messages.append(
        HumanMessage(content=user_msg)
    )

    try:
        # Get AI response
        response = model.invoke(messages)

        # Print response
        print("Bot:", response.content)
        print()

        # Save response to history
        messages.append(
            AIMessage(content=response.content)
        )

    except Exception as e:
        print("\n❌ Error:", e)
        print()
# Out:
# ✅ API key found
#
# ...
#         GROQ AI CHATBOT
# ...
# Type 'exit' or 'quit' to stop.
#
# You: whats mcp, visualize
# Bot: **MCP** can mean different things depending on the field.
# Here are the most common meanings, plus a quick visual for each so you can see what’s being talked about.
#
# | Field | What “MCP” usually stands for | Quick visual |
# |-------|------------------------------|--------------|
# | **Computer hardware** | **Microchip (MCP)** – a brand prefix for a family of integrated circuits (e.g., MCP3008 ADC, MCP2515 CAN controller) | ![MCP3008 pinout diagram](https://i.imgur.com/1bYxXJ9.png)<br>*Typical 16‑pin MCP3008 ADC pinout* |
# | **Computer science** | **Master Control Program** – an early operating‑system concept (think of a mainframe “control” layer) | ![MCP architecture](https://i.imgur.com/8Y9rZ5a.png)<br>*Simplified view of a Master Control Program managing tasks* |
# ...
